# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/netflix_titles.csv')

# %% [markdown]
# Быстрый обзор данных

# %%
df.head(5)
df.info()
df.isnull().sum()

# %%
#Очистка данных
df["date_added"] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year

# %%
# import pandas as pd
# df = pd.read_csv('data/raw/netflix_titles.csv')
# print(df.isna().sum())

# df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# df_genres = (df.assign(genre=df['listed_in'].str.split(','))
#                .explode('genre').assign(genre=lambda d: d['genre'].str.strip()))

# df_countries = (df.assign(country=df['country'].str.split(','))
#                  .explode('country').assign(country=lambda d: d['country'].str.strip()))

# df_genres.to_csv('data/processed/genres.csv', index=False)
# df_countries.to_csv('data/processed/countries.csv', index=False)
# df.to_csv('data/processed/main.csv', index=False)


# #EDA (02_eda.ipynb)
# import seaborn as sns, matplotlib.pyplot as plt, plotly.express as px
# sns.countplot(data=df_genres, y='genre', order=df_genres['genre'].value_counts().index)

# year_cnt = df.groupby('release_year').size().reset_index(name='n')
# px.line(year_cnt, x='release_year', y='n')

# top_c = df_countries['country'].value_counts().head(10).reset_index()
# px.bar(top_c, x='index', y='country')
